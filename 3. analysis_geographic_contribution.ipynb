# %%
import pandas as pd
import numpy as np
import re
from functools import reduce
import seaborn as sns
import missingno as msno
# %matplotlib inline

import matplotlib.pyplot as plt
from scipy.stats import norm

# %%
# Set the figure size - handy for larger output
from matplotlib import pyplot as plt
plt.rcParams["figure.figsize"] = [10, 6]
# Set up with a higher resolution screen (useful on Mac)
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ## import data

# %%
data = pd.read_pickle('D:\MARBURG VIRUS DISEASES\DATA_PREPROCESSING/data_concat_countries_and_wb_groups_income.pkl')#.drop(['Addresses'], axis=1)

data.head(2)
# Out:
#                 wos_ID                                          Addresses  \
# 0  wos:000904661800001  [Bi, Jinhao; Xia, Xianzhu] Jilin Agr Univ, Col...
# 1  wos:000921279800001  [Ye, Xin; Holland, Richard; Wood, Mark; Pasetk...
#
#    Afghanistan  United States  Angola  Argentina  Australia  Austria  \
# 0          NaN            NaN     NaN        NaN        NaN      NaN
# 1          NaN            2.0     NaN        NaN        NaN      NaN
#
#    Bangladesh  Belgium  ...  wb_lower_middle_income_economies  \
# 0         NaN      NaN  ...                               NaN
# 1         NaN      NaN  ...                               NaN
#
#    wb_lower_middle_income_economies_africa  \
# 0                                      NaN
# 1                                      NaN
#
#    wb_lower_middle_income_economies_others  wb_upper_middle_income_economies  \
# 0                                      NaN                               1.0
# 1                                      NaN                               NaN
#
#    wb_upper_middle_income_economies_africa  \
# 0                                      NaN
# 1                                      NaN
#
#    wb_upper_middle_income_economies_others  wb_high_income_economies  \
# 0                                      1.0                       NaN
# 1                                      NaN                       2.0
#
#    wb_high_income_economies_others  funding_yes  open_access_yes
# 0                              NaN            0                1
# 1                              2.0            1                1
#
# [2 rows x 122 columns]

# %%
data.count().head(10)
# Out:
# wos_ID           932
# Addresses        876
# Afghanistan        1
# United States    586
# Angola             2
# Argentina          1
# Australia         18
# Austria            4
# Bangladesh         5
# Belgium           24
# dtype: int64

# %% [markdown]
# # The Geographic contribution to Marburg Virus Diseases publications
#
# ## Proportion of publications by countries

# %%
countries_list = data.count().to_frame().sort_values(by=0, ascending=False)
countries_list['%'] = countries_list[0]/countries_list.T['Addresses'][0]*100
# save data
countries_list.to_csv(f'../TABLES/countries_list.csv')

countries_list.head(60)
# Out:
#                                            0           %
# wos_ID                                   932  106.392694
# funding_yes                              932  106.392694
# open_access_yes                          932  106.392694
# year_group                               927  105.821918
# Publication Year                         927  105.821918
# Since 2013 Usage Count                   895  102.168950
# Addresses                                876  100.000000
# Times Cited, All Databases               871   99.429224
# non_african_countries                    860   98.173516
# wb_high_income_economies_others          820   93.607306
# wb_high_income_economies                 820   93.607306
# Open Access Designations                 673   76.826484
# wb_north_america                         611   69.748858
# United States                            586   66.894977
# Funding Orgs                             577   65.867580
# 180 Day Usage Count                      312   35.616438
# wb_europe_and_central_asia               302   34.474886
# Germany                                  149   17.009132
# wb_east_asia_and_pacific                 126   14.383562
# wb_sub_saharan_africa                    125   14.269406
# wb_upper_middle_income_economies         118   13.470320
# wb_upper_middle_income_economies_others   87    9.931507
# wb_low_income_economies                   80    9.132420
# Canada                                    71    8.105023
# wb_low_income_economies_africa            70    7.990868
# United Kingdom                            69    7.876712
# wb_lower_middle_income_economies          56    6.392694
# Japan                                     52    5.936073
# Southern_africa                           48    5.479452
# eastern_africa                            45    5.136986
# China                                     45    5.136986
# France                                    38    4.337900
# wb_upper_middle_income_economies_africa   38    4.337900
# Central_africa                            37    4.223744
# wb_lower_middle_income_economies_africa   37    4.223744
# Uganda                                    32    3.652968
# South Africa                              32    3.652968
# Switzerland                               26    2.968037
# Belgium                                   24    2.739726
# wb_lower_middle_income_economies_others   23    2.625571
# Russia                                    22    2.511416
# Western_africa                            21    2.397260
# wb_south_asia                             19    2.168950
# DR Congo                                  18    2.054795
# Australia                                 18    2.054795
# Netherlands                               18    2.054795
# wb_middle_east_and_north_africa           18    2.054795
# India                                     15    1.712329
# Spain                                     15    1.712329
# Italy                                     14    1.598174
# Zambia                                    14    1.598174
# wb_middle_east_and_north_africa_others    12    1.369863
# Sweden                                    10    1.141553
# north_africa                               8    0.913242
# wb_middle_east_and_north_africa_africa     8    0.913242
# Gabon                                      8    0.913242
# Singapore                                  8    0.913242
# Egypt                                      7    0.799087
# wb_latin_america_and_the_caribbean         7    0.799087
# Congo Republic                             7    0.799087

# %% [markdown]
# ## Proportion of publications  by countries and funding

# %%
countries_fund_list = data.reset_index().groupby(['funding_yes']).count().T
countries_fund_list.rename(columns = {0:'no_fund', 
                              1:'fund'}, inplace = True)

countries_fund_list['total'] = countries_fund_list['no_fund'] + countries_fund_list['fund']

for col in countries_fund_list.columns:
    countries_fund_list['%_'+col] = countries_fund_list[col]/countries_fund_list['total']*100
    
countries_fund_list['%_diff(%_fund-%_no_fund)'] = countries_fund_list['%_fund'] - countries_fund_list['%_no_fund']

# save data
countries_fund_list.to_csv(f'../TABLES/countries_fund_list.csv')

countries_fund_list
# Out:
# funding_yes                              no_fund  fund  total   %_no_fund  \
# index                                        355   577    932   38.090129
# wos_ID                                       355   577    932   38.090129
# Addresses                                    299   577    876   34.132420
# Afghanistan                                    1     0      1  100.000000
# United States                                152   434    586   25.938567
# ...                                          ...   ...    ...         ...
# wb_upper_middle_income_economies_africa       19    19     38   50.000000
# wb_upper_middle_income_economies_others       21    66     87   24.137931
# wb_high_income_economies                     274   546    820   33.414634
# wb_high_income_economies_others              274   546    820   33.414634
# open_access_yes                              355   577    932   38.090129
#
# funding_yes                                 %_fund  %_total  \
# index                                    61.909871    100.0
# wos_ID                                   61.909871    100.0
# Addresses                                65.867580    100.0
# Afghanistan                               0.000000    100.0
# United States                            74.061433    100.0
# ...                                            ...      ...
# wb_upper_middle_income_economies_africa  50.000000    100.0
# wb_upper_middle_income_economies_others  75.862069    100.0
# wb_high_income_economies                 66.585366    100.0
# wb_high_income_economies_others          66.585366    100.0
# open_access_yes                          61.909871    100.0
#
# funding_yes                              %_diff(%_fund-%_no_fund)
# index                                                   23.819742
# wos_ID                                                  23.819742
# Addresses                                               31.735160
# Afghanistan                                           -100.000000
# United States                                           48.122867
# ...                                                           ...
# wb_upper_middle_income_economies_africa                  0.000000
# wb_upper_middle_income_economies_others                 51.724138
# wb_high_income_economies                                33.170732
# wb_high_income_economies_others                         33.170732
# open_access_yes                                         23.819742
#
# [122 rows x 7 columns]

# %%
countries_list = [ 'Afghanistan', 'United States', 'Angola', 'Argentina', 'Australia', 'Austria', 'Bangladesh', 'Belgium', 'Belize', 'Brazil', 'Bulgaria', 'Burkina Faso',
 'Canada', 'Central African Republic', 'Colombia', 'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Czech Republic',
 'DR Congo', 'Denmark', 'Ecuador', 'Egypt', 'United Kingdom', 'Germany', 'Finland', 'France', 'Gabon', 'Ghana', 'Greece', 'Guinea', 'Honduras', 'Hungary',
 'India', 'Indonesia', 'Iran', 'Iraq', 'Israel', 'Italy', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya', 'Lebanon', 'Malawi', 'Malaysia', 'Mali', 'Morocco',
 'Nepal', 'Netherlands', 'New Zealand', 'Nigeria', 'Norway', 'Pakistan', 'Palestine', 'Panama', 'China', 'Peru', 'Philippines', 'Poland', 'Portugal',
 'Congo Republic', 'Russia', 'Saudi Arabia', 'Senegal', 'Serbia', 'Sierra Leone', 'Singapore', 'Slovakia', 'South Africa', 'South Korea', 'Spain', 'Sweden',
 'Switzerland', 'Tanzania', 'Thailand', 'Turkey', 'United Arab Emirates', 'Uganda', 'Ukraine', 'Venezuela', 'Vietnam', 'Zambia', 'Zimbabwe', 'Sudan']

# %%
region_wb = ['wb_east_asia_and_pacific', 'wb_europe_and_central_asia', 'wb_latin_america_and_the_caribbean', 'wb_middle_east_and_north_africa', 
               'wb_middle_east_and_north_africa_africa', 'wb_middle_east_and_north_africa_others', 'wb_north_america', 'wb_south_asia', 'wb_sub_saharan_africa',
                 ]

# %%
income_wb = ['wb_low_income_economies',  'wb_lower_middle_income_economies', 
               'wb_upper_middle_income_economies', 'wb_high_income_economies'
                  ]

# %%
countries_fund_list.reset_index()[countries_fund_list.reset_index()['index'].isin(countries_list)].describe()
# Out:
# funding_yes     no_fund        fund       total   %_no_fund      %_fund  \
# count         85.000000   85.000000   85.000000   85.000000   85.000000
# mean           5.623529   11.282353   16.905882   41.434877   58.565123
# std           18.103523   48.243581   65.799049   38.086915   38.086915
# min            0.000000    0.000000    1.000000    0.000000    0.000000
# 25%            0.000000    1.000000    1.000000    0.000000   33.333333
# 50%            1.000000    1.000000    3.000000   41.610738   58.389262
# 75%            3.000000    6.000000    8.000000   66.666667  100.000000
# max          152.000000  434.000000  586.000000  100.000000  100.000000
#
# funding_yes  %_total  %_diff(%_fund-%_no_fund)
# count           85.0                 85.000000
# mean           100.0                 17.130246
# std              0.0                 76.173830
# min            100.0               -100.000000
# 25%            100.0                -33.333333
# 50%            100.0                 16.778523
# 75%            100.0                100.000000
# max            100.0                100.000000

# %%
countries_fund_list.reset_index()[countries_fund_list.reset_index()['index'].isin(region_wb)].describe()
# Out:
# funding_yes     no_fund        fund       total  %_no_fund     %_fund  \
# count          9.000000    9.000000    9.000000   9.000000   9.000000
# mean          44.555556   91.888889  136.444444  45.923134  54.076866
# std           60.291192  146.938290  202.920619  21.667549  21.667549
# min            3.000000    1.000000    7.000000  18.253968  12.500000
# 25%            7.000000    6.000000   12.000000  33.333333  44.444444
# 50%           13.000000    8.000000   19.000000  42.857143  57.142857
# 75%           45.000000  103.000000  126.000000  55.555556  66.666667
# max          159.000000  452.000000  611.000000  87.500000  81.746032
#
# funding_yes  %_total  %_diff(%_fund-%_no_fund)
# count            9.0                  9.000000
# mean           100.0                  8.153732
# std              0.0                 43.335099
# min            100.0                -75.000000
# 25%            100.0                -11.111111
# 50%            100.0                 14.285714
# 75%            100.0                 33.333333
# max            100.0                 63.492063

# %%
countries_fund_list.reset_index()[countries_fund_list.reset_index()['index'].isin(income_wb)].describe()
# Out:
# funding_yes     no_fund        fund      total  %_no_fund     %_fund  %_total  \
# count          4.000000    4.000000    4.00000   4.000000   4.000000      4.0
# mean          91.750000  176.750000  268.50000  37.475935  62.524065    100.0
# std          121.606949  247.115864  368.55167   9.553771   9.553771      0.0
# min           26.000000   27.000000   56.00000  32.203390  48.214286    100.0
# 25%           28.250000   47.250000   74.00000  32.425847  61.992596    100.0
# 50%           33.500000   67.000000   99.00000  32.957317  67.042683    100.0
# 75%           97.000000  196.500000  293.50000  38.007404  67.574153    100.0
# max          274.000000  546.000000  820.00000  51.785714  67.796610    100.0
#
# funding_yes  %_diff(%_fund-%_no_fund)
# count                        4.000000
# mean                        25.048131
# std                         19.107542
# min                         -3.571429
# 25%                         23.985192
# 50%                         34.085366
# 75%                         35.148305
# max                         35.593220
